# %% [markdown]
# <a href="https://colab.research.google.com/github/Rahi20028/learning-AIML/blob/main/pandas.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd

# %%
#series : a one-dimensional labeled array
s1= pd.Series([1,2,3])
print(s1)
# Out:
# 0    1
# 1    2
# 2    3
# dtype: int64

# %%
s2= pd.Series([10,9,8,7,6], ["A","B","C","D","E"])
s2
# Out:
# A    10
# B     9
# C     8
# D     7
# E     6
# dtype: int64

# %%
s1.values
# Out:
# array([1, 2, 3])

# %%
s2.values
# Out:
# array([10,  9,  8,  7,  6])

# %%
s2.index
# Out:
# Index(['A', 'B', 'C', 'D', 'E'], dtype='object')

# %%
#create dataframe from list of dict
#pd.DataFrame(data,index,columns)
data = [{'name': 'rahi','marks': 28},
        {'name': 'chhaya', 'marks':27},
        {'name': 'niva', 'marks': 36}]
f1 =pd.DataFrame(data)
f1
# Out:
#      name  marks
# 0    rahi     28
# 1  chhaya     27
# 2    niva     36

# %%
type(data)
# Out:
# list

# %%
type(f1)
# Out:
# pandas.core.frame.DataFrame

# %%
#create dataframe with some missing values - NAN
data1 = pd.DataFrame([{'rahi':20, 'niva':25, 'chhaya': 18},{'rahi':28,'dhyana':20,'sanvi':20}])
index= ['maths','physics']
data1
# Out:
#    rahi  niva  chhaya  dhyana  sanvi
# 0    20  25.0    18.0     NaN    NaN
# 1    28   NaN     NaN    20.0   20.0

# %%
data1.isna().sum()
# Out:
# rahi      0
# niva      1
# chhaya    1
# dhyana    1
# sanvi     1
# dtype: int64

# %%
data1.fillna(data1.mean(), inplace=True)
data1
# Out:
#    rahi  niva  chhaya  dhyana  sanvi
# 0    20  25.0    18.0    20.0   20.0
# 1    28  25.0    18.0    20.0   20.0
# <h4 class="colab-quickchart-section-title">Distributions</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# from matplotlib import pyplot as plt
# _df_0['index'].plot(kind='hist', bins=20, title='index')
# plt.gca().spines[['top', 'right',]].set_visible(False)
# from matplotlib import pyplot as plt
# _df_1['rahi'].plot(kind='hist', bins=20, title='rahi')
# plt.gca().spines[['top', 'right',]].set_visible(False)
# <h4 class="colab-quickchart-section-title">2-d distributions</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# from matplotlib import pyplot as plt
# _df_2.plot(kind='scatter', x='index', y='rahi', s=32, alpha=.8)
# plt.gca().spines[['top', 'right',]].set_visible(False)
# <h4 class="colab-quickchart-section-title">Time series</h4>
# <style>
# ...

# %%
student= pd.read_excel('/content/drive/MyDrive/Rahi_AIML/2.Data science/2_Pandas/sample excel.xlsx')
student
# Out:
#    Unnamed: 0   name  marks
# 0           0   john     76
# 1           1  alice     54
# 2           2    bob     32
# 3           3   emma     76
# 4           4  james     87

# %%
iris = pd.read_csv('/content/drive/MyDrive/Rahi_AIML/2.Data science/2_Pandas/iris.csv')
iris
# Out:
#      Sepal.Length  Sepal.Width  Petal.Length  Petal.Width    Species
# 0             5.1          3.5           1.4          0.2     setosa
# 1             4.9          3.0           1.4          0.2     setosa
# 2             4.7          3.2           1.3          0.2     setosa
# 3             4.6          3.1           1.5          0.2     setosa
# 4             5.0          3.6           1.4          0.2     setosa
# ..            ...          ...           ...          ...        ...
# 145           6.7          3.0           5.2          2.3  virginica
# 146           6.3          2.5           5.0          1.9  virginica
# 147           6.5          3.0           5.2          2.0  virginica
# 148           6.2          3.4           5.4          2.3  virginica
# 149           5.9          3.0           5.1          1.8  virginica
#
# [150 rows x 5 columns]

# %%
iris.head()
# Out:
#    Sepal.Length  Sepal.Width  Petal.Length  Petal.Width Species
# 0           5.1          3.5           1.4          0.2  setosa
# 1           4.9          3.0           1.4          0.2  setosa
# 2           4.7          3.2           1.3          0.2  setosa
# 3           4.6          3.1           1.5          0.2  setosa
# 4           5.0          3.6           1.4          0.2  setosa

# %%
iris.tail()
# Out:
#      Sepal.Length  Sepal.Width  Petal.Length  Petal.Width    Species
# 145           6.7          3.0           5.2          2.3  virginica
# 146           6.3          2.5           5.0          1.9  virginica
# 147           6.5          3.0           5.2          2.0  virginica
# 148           6.2          3.4           5.4          2.3  virginica
# 149           5.9          3.0           5.1          1.8  virginica

# %%
iris.index
# Out:
# RangeIndex(start=0, stop=150, step=1)

# %%
iris.columns
# Out:
# Index(['Sepal.Length', 'Sepal.Width', 'Petal.Length', 'Petal.Width',
#        'Species'],
#       dtype='object')

# %%
iris=iris.rename(columns={'Sepal.Length':'Sepal_Length','Sepal.Width':'Sepal_Width','Petal.Length':'Petal_Length','PetalWidthCm':'Petal_width'})
iris
# Out:
#      Sepal_Length  Sepal_Width  Petal_Length  Petal.Width    Species
# 0             5.1          3.5           1.4          0.2     setosa
# 1             4.9          3.0           1.4          0.2     setosa
# 2             4.7          3.2           1.3          0.2     setosa
# 3             4.6          3.1           1.5          0.2     setosa
# 4             5.0          3.6           1.4          0.2     setosa
# ..            ...          ...           ...          ...        ...
# 145           6.7          3.0           5.2          2.3  virginica
# 146           6.3          2.5           5.0          1.9  virginica
# 147           6.5          3.0           5.2          2.0  virginica
# 148           6.2          3.4           5.4          2.3  virginica
# 149           5.9          3.0           5.1          1.8  virginica
#
# [150 rows x 5 columns]

# %%
categories = iris['Species'].unique()
print("categories in the iris dataset:", categories)
# Out:
# categories in the iris dataset: ['setosa' 'versicolor' 'virginica']

# %%
iris.replace("setosa", "set",inplace=True)
iris.replace("virginica", "virg",inplace=True)
iris
# Out:
#      Sepal_Length  Sepal_Width  Petal_Length  Petal.Width Species
# 0             5.1          3.5           1.4          0.2     set
# 1             4.9          3.0           1.4          0.2     set
# 2             4.7          3.2           1.3          0.2     set
# 3             4.6          3.1           1.5          0.2     set
# 4             5.0          3.6           1.4          0.2     set
# ..            ...          ...           ...          ...     ...
# 145           6.7          3.0           5.2          2.3    virg
# 146           6.3          2.5           5.0          1.9    virg
# 147           6.5          3.0           5.2          2.0    virg
# 148           6.2          3.4           5.4          2.3    virg
# 149           5.9          3.0           5.1          1.8    virg
#
# [150 rows x 5 columns]

# %%
iris.describe()
# Out:
#        Sepal_Length  Sepal_Width  Petal_Length  Petal.Width
# count    150.000000   150.000000    150.000000   150.000000
# mean       5.843333     3.057333      3.758000     1.199333
# std        0.828066     0.435866      1.765298     0.762238
# min        4.300000     2.000000      1.000000     0.100000
# 25%        5.100000     2.800000      1.600000     0.300000
# 50%        5.800000     3.000000      4.350000     1.300000
# 75%        6.400000     3.300000      5.100000     1.800000
# max        7.900000     4.400000      6.900000     2.500000

# %%
iris[['Sepal_Length']].head()
# Out:
#    Sepal_Length
# 0           5.1
# 1           4.9
# 2           4.7
# 3           4.6
# 4           5.0

# %%
iris[[
    'Sepal_Length']].head(3)
# Out:
#    Sepal_Length
# 0           5.1
# 1           4.9
# 2           4.7

# %%
#g. add new column with condition
def yes_no(Sepal_Length):
  return 'YES' if Sepal_Length >= 5 else 'NO'
#apply function to create new column
iris['Result'] = iris['Sepal_Length'].apply(yes_no)
iris
# Out:
#      Sepal_Length  Sepal_Width  Petal_Length  Petal.Width Species Result
# 0             5.1          3.5           1.4          0.2     set    YES
# 1             4.9          3.0           1.4          0.2     set     NO
# 2             4.7          3.2           1.3          0.2     set     NO
# 3             4.6          3.1           1.5          0.2     set     NO
# 4             5.0          3.6           1.4          0.2     set    YES
# ..            ...          ...           ...          ...     ...    ...
# 145           6.7          3.0           5.2          2.3    virg    YES
# 146           6.3          2.5           5.0          1.9    virg    YES
# 147           6.5          3.0           5.2          2.0    virg    YES
# 148           6.2          3.4           5.4          2.3    virg    YES
# 149           5.9          3.0           5.1          1.8    virg    YES
#
# [150 rows x 6 columns]

# %%
iris.drop('Result', axis=1, inplace=True)
iris
# Out:
#      Sepal_Length  Sepal_Width  Petal_Length  Petal.Width Species
# 0             5.1          3.5           1.4          0.2     set
# 1             4.9          3.0           1.4          0.2     set
# 2             4.7          3.2           1.3          0.2     set
# 3             4.6          3.1           1.5          0.2     set
# 4             5.0          3.6           1.4          0.2     set
# ..            ...          ...           ...          ...     ...
# 145           6.7          3.0           5.2          2.3    virg
# 146           6.3          2.5           5.0          1.9    virg
# 147           6.5          3.0           5.2          2.0    virg
# 148           6.2          3.4           5.4          2.3    virg
# 149           5.9          3.0           5.1          1.8    virg
#
# [150 rows x 5 columns]

# %%
iris.iloc[0]
# Out:
# Sepal_Length    5.1
# Sepal_Width     3.5
# Petal_Length    1.4
# Petal.Width     0.2
# Species         set
# Name: 0, dtype: object

# %%
iris.iloc[51:56]
# Out:
#     Sepal_Length  Sepal_Width  Petal_Length  Petal.Width     Species
# 51           6.4          3.2           4.5          1.5  versicolor
# 52           6.9          3.1           4.9          1.5  versicolor
# 53           5.5          2.3           4.0          1.3  versicolor
# 54           6.5          2.8           4.6          1.5  versicolor
# 55           5.7          2.8           4.5          1.3  versicolor

# %%
iris[iris['Petal_Length']>5]
# Out:
#      Sepal_Length  Sepal_Width  Petal_Length  Petal.Width     Species
# 83            6.0          2.7           5.1          1.6  versicolor
# 100           6.3          3.3           6.0          2.5        virg
# 101           5.8          2.7           5.1          1.9        virg
# 102           7.1          3.0           5.9          2.1        virg
# 103           6.3          2.9           5.6          1.8        virg
# 104           6.5          3.0           5.8          2.2        virg
# 105           7.6          3.0           6.6          2.1        virg
# 107           7.3          2.9           6.3          1.8        virg
# 108           6.7          2.5           5.8          1.8        virg
# 109           7.2          3.6           6.1          2.5        virg
# 110           6.5          3.2           5.1          2.0        virg
# 111           6.4          2.7           5.3          1.9        virg
# ...

# %%
iris[iris['Species']=='Iris-virginica'].count()
# Out:
# Sepal_Length    0
# Sepal_Width     0
# Petal_Length    0
# Petal.Width     0
# Species         0
# dtype: int64

# %%
iris[ (iris['Sepal_Length'] > 6) & (iris['Species'] == "virg") ]
# Out:
#      Sepal_Length  Sepal_Width  Petal_Length  Petal.Width Species
# 100           6.3          3.3           6.0          2.5    virg
# 102           7.1          3.0           5.9          2.1    virg
# 103           6.3          2.9           5.6          1.8    virg
# 104           6.5          3.0           5.8          2.2    virg
# 105           7.6          3.0           6.6          2.1    virg
# 107           7.3          2.9           6.3          1.8    virg
# 108           6.7          2.5           5.8          1.8    virg
# 109           7.2          3.6           6.1          2.5    virg
# 110           6.5          3.2           5.1          2.0    virg
# 111           6.4          2.7           5.3          1.9    virg
# 112           6.8          3.0           5.5          2.1    virg
# 115           6.4          3.2           5.3          2.3    virg
# 116           6.5          3.0           5.5          1.8    virg
# ...

# %%
iris.duplicated()
# Out:
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False
#        ...
# 145    False
# 146    False
# 147    False
# 148    False
# 149    False
# Length: 150, dtype: bool

# %%
iris.duplicated().sum()
# Out:
# np.int64(1)

# %%
iris.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 150 entries, 0 to 149
# Data columns (total 5 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Sepal_Length  150 non-null    float64
#  1   Sepal_Width   150 non-null    float64
#  2   Petal_Length  150 non-null    float64
#  3   Petal.Width   150 non-null    float64
#  4   Species       150 non-null    object
# dtypes: float64(4), object(1)
# memory usage: 6.0+ KB

# %%
iris.isna()
# Out:
#      Sepal_Length  Sepal_Width  Petal_Length  Petal.Width  Species
# 0           False        False         False        False    False
# 1           False        False         False        False    False
# 2           False        False         False        False    False
# 3           False        False         False        False    False
# 4           False        False         False        False    False
# ..            ...          ...           ...          ...      ...
# 145         False        False         False        False    False
# 146         False        False         False        False    False
# 147         False        False         False        False    False
# 148         False        False         False        False    False
# 149         False        False         False        False    False
#
# [150 rows x 5 columns]

# %%
iris.isna().sum()
# Out:
# Sepal_Length    0
# Sepal_Width     0
# Petal_Length    0
# Petal.Width     0
# Species         0
# dtype: int64

# %%
pip install ucimlrepo

# %%
from ucimlrepo import fetch_ucirepo
adult = fetch_ucirepo(id=2)
x= adult.data.features
y=adult.data.targets
print(adult.metadata)
print(adult.variables)
# Out:
# {'uci_id': 2, 'name': 'Adult', 'repository_url': 'https://archive.ics.uci.edu/dataset/2/adult', 'data_url': 'https://archive.ics.uci.edu/static/public/2/data.csv', 'abstract': 'Predict whether annual income of an individual exceeds $50K/yr based on census data. Also known as "Census Income" dataset. ', 'area': 'Social Science', 'tasks': ['Classification'], 'characteristics': ['Multivariate'], 'num_instances': 48842, 'num_features': 14, 'feature_types': ['Categorical', 'Integer'], 'demographics': ['Age', 'Income', 'Education Level', 'Other', 'Race', 'Sex'], 'target_col': ['income'], 'index_col': None, 'has_missing_values': 'yes', 'missing_values_symbol': 'NaN', 'year_of_dataset_creation': 1996, 'last_updated': 'Tue Sep 24 2024', 'dataset_doi': '10.24432/C5XW20', 'creators': ['Barry Becker', 'Ronny Kohavi'], 'intro_paper': None, 'additional_info': {'summary': "Extraction was done by Barry Becker from the 1994 Census database.  A set of reasonably clean records was extracted using the f
# ...

# %%
x.isna().sum()
# Out:
# age                 0
# workclass         963
# fnlwgt              0
# education           0
# education-num       0
# marital-status      0
# occupation        966
# relationship        0
# race                0
# sex                 0
# capital-gain        0
# capital-loss        0
# hours-per-week      0
# native-country    274
# dtype: int64

# %%
x['workclass'].unique()
# Out:
# array(['State-gov', 'Self-emp-not-inc', 'Private', 'Federal-gov',
#        'Local-gov', '?', 'Self-emp-inc', 'Without-pay', 'Never-worked',
#        nan], dtype=object)
